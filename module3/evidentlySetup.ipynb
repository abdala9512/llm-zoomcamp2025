# %% [markdown]
# # Evidently Service

# %%
from evidently.ui.workspace import RemoteWorkspace

remote_ws = RemoteWorkspace("http://127.0.0.1:8000")
remote_ws

# %%
remote_ws.create_project("llm_zoomcamp2025")
# Out:
# Project ID: 0197fa6b-df25-7dce-8250-1dfe80b907f8
# Project Name: llm_zoomcamp2025
# Project Description: None
